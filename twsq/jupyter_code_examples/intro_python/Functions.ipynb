# %% [markdown]
#  # Functions

# %%
# create functions using the def keyword
# function arguments are specified in () above
# "return" keyword specifies function output
    
def add_2(x):     
    result = x + 2
    return result

print (add_2(0))
print (add_2(4))
# Out:
# 2
# 6

# %%
# body of function should be indented with tab
def add_2(x):     
    result = x + 2
    return result

print (add_2(0))
print (add_2(4))
# Out:
# 2
# 6

# %%
# functions can have multiple arguments

def divide(x,y):     
    result = x/y
    return result

print (divide(2,2))
print (divide(5,3))
print (divide(3,5))
print (divide(y=3,x=5))
# Out:
# 1.0
# 1.6666666666666667
# 0.6
# 1.6666666666666667

# %%
# function arguments can have defaults 

def multiply(x,y=2,z=1):
    result = x*y*z
    return result

print(multiply(2))
print(multiply(2,3))
print(multiply(2,z=2))
# Out:
# 4
# 6
# 8

# %%
# function arguments can be of many types

def in_list_or(a_list, item1, item2):
    result = (item1 in a_list) or (item2 in a_list)    
    return result

print (in_list_or(['XOM','GS','WMT'],'XOM','AAPL'))
# Out:
# True

# %%
in_list_or(1,'XOM','AAPL')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 in_list_or(1,'XOM','AAPL')
#
# Cell In[6], line 4, in in_list_or(a_list, item1, item2)
#       3 def in_list_or(a_list, item1, item2):
# ----> 4     result = (item1 in a_list) or (item2 in a_list)
#       5     return result
#
# TypeError: argument of type 'int' is not iterable

# %%
in_list_or('ABC','XOM','AAPL')
# Out:
# False
