# %% [markdown]
# # Reindexing
# 1. Series
# 2. DataFrame

# %%
import pandas as pd 

# series reindexing
ser=pd.Series({'AAPL':-0.01,'MSFT':-0.02,'TSLA':0.015})
ser
# Out:
# AAPL   -0.010
# MSFT   -0.020
# TSLA    0.015
# dtype: float64

# %%
# re-order existing index and add new ticker 
ser.reindex(['TSLA','LULU','AAPL','MSFT'])
# Out:
# TSLA    0.015
# LULU      NaN
# AAPL   -0.010
# MSFT   -0.020
# dtype: float64

# %%
# standard series retrieval does not let you pass new items
ser[['TSLA','LULU','AAPL','MSFT']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 # standard series retrieval does not let you pass new items
# ----> 2 ser[['TSLA','LULU','AAPL','MSFT']]
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/series.py:991, in Series.__getitem__(self, key)
#     988     key = np.asarray(key, dtype=bool)
#     989     return self._get_rows_with_mask(key)
# --> 991 return self._get_with(key)
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/series.py:1003, in Series._get_with(self, key)
#    1000 elif isinstance(key, tuple):
#    1001     return self._get_values_tuple(key)
# -> 1003 return self.loc[key]
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['LULU'] not in index"

# %%
# However, you can re-order existing entries using standard series retrieval
ser[['TSLA','AAPL','MSFT']]
# Out:
# TSLA    0.015
# AAPL   -0.010
# MSFT   -0.020
# dtype: float64

# %%
# If you just want to exclude entries, use drop
ser.drop('TSLA')
# Out:
# AAPL   -0.01
# MSFT   -0.02
# dtype: float64

# %%
# DataFrame Reindexing
data = {'AAPL':[-0.01,0.015,-0.025,-0.03],
        'MSFT':[0.03,0.005,0.0015,0.015],
        'TSLA':[0.05,-0.05,-0.2,0.03],
       }

index=['20201201','20201202','20201203','20201204']
df=pd.DataFrame(data,index=index)
df
# Out:
#            AAPL    MSFT  TSLA
# 20201201 -0.010  0.0300  0.05
# 20201202  0.015  0.0050 -0.05
# 20201203 -0.025  0.0015 -0.20
# 20201204 -0.030  0.0150  0.03

# %%
new_index = ['20201205','20201204','20201203','20201202','20201201','20201130']
df.reindex(new_index)
# Out:
#            AAPL    MSFT  TSLA
# 20201205    NaN     NaN   NaN
# 20201204 -0.030  0.0150  0.03
# 20201203 -0.025  0.0015 -0.20
# 20201202  0.015  0.0050 -0.05
# 20201201 -0.010  0.0300  0.05
# 20201130    NaN     NaN   NaN

# %%
new_columns=['TSLA','LULU','AAPL','MSFT']
df.reindex(new_index,columns=new_columns)
# Out:
#           TSLA  LULU   AAPL    MSFT
# 20201205   NaN   NaN    NaN     NaN
# 20201204  0.03   NaN -0.030  0.0150
# 20201203 -0.20   NaN -0.025  0.0015
# 20201202 -0.05   NaN  0.015  0.0050
# 20201201  0.05   NaN -0.010  0.0300
# 20201130   NaN   NaN    NaN     NaN

# %%
# Loc only allows you to reindex with existing entries
df.loc[new_index,new_columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Loc only allows you to reindex with existing entries
# ----> 2 df.loc[new_index,new_columns]
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1093, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1089 for i, key in zip(range(len(tup) - 1, -1, -1), reversed(tup), strict=True):
#    1090     if is_label_like(key) or is_list_like(key):
#    1091         # We don't need to check for tuples here because those are
#    1092         #  caught by the _is_nested_tuple_indexer check above.
# -> 1093         section = self._getitem_axis(key, axis=i)
#    1095         # We should never have a scalar section here, because
#    1096         #  _getitem_lowerdim is only called after a check for
#    1097         #  is_scalar_access, which that would be.
#    1098         if section.ndim == self.ndim:
#    1099             # we're in the middle of slicing through a MultiIndex
#    1100             # revise the key wrt to `section` by inserting an _NS
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['LULU'] not in index"

# %%
df.loc[['20201204','20201203','20201202','20201201'],['TSLA','AAPL','MSFT']]
# Out:
#           TSLA   AAPL    MSFT
# 20201204  0.03 -0.030  0.0150
# 20201203 -0.20 -0.025  0.0015
# 20201202 -0.05  0.015  0.0050
# 20201201  0.05 -0.010  0.0300

# %%
# Dropping
df.drop('20201204')
# Out:
#            AAPL    MSFT  TSLA
# 20201201 -0.010  0.0300  0.05
# 20201202  0.015  0.0050 -0.05
# 20201203 -0.025  0.0015 -0.20

# %%
df.drop('TSLA',axis=1)
# Out:
#            AAPL    MSFT
# 20201201 -0.010  0.0300
# 20201202  0.015  0.0050
# 20201203 -0.025  0.0015
# 20201204 -0.030  0.0150

# %% [markdown]
# # Sorting
# 1. Series
# 2. DataFrame

# %%
# series sorting
ser=pd.Series([-0.01,0.02,-0.005,-0.02],index=['20201203','20201202','20201204','20201201'])
ser
# Out:
# 20201203   -0.010
# 20201202    0.020
# 20201204   -0.005
# 20201201   -0.020
# dtype: float64

# %%
ser.sort_index()
# Out:
# 20201201   -0.020
# 20201202    0.020
# 20201203   -0.010
# 20201204   -0.005
# dtype: float64

# %%
ser.sort_index(ascending=False)
# Out:
# 20201204   -0.005
# 20201203   -0.010
# 20201202    0.020
# 20201201   -0.020
# dtype: float64

# %%
ser.sort_values()
# Out:
# 20201201   -0.020
# 20201203   -0.010
# 20201204   -0.005
# 20201202    0.020
# dtype: float64

# %%
# DataFrame Reindexing
data = {'AAPL':[-0.01,0.015,-0.025,-0.03],
        'MSFT':[0.03,0.005,0.0015,0.015],
        'TSLA':[0.05,-0.05,-0.2,0.03],
       }

index=['20201201','20201204','20201203','20201202']
df=pd.DataFrame(data,index=index)
df
# Out:
#            AAPL    MSFT  TSLA
# 20201201 -0.010  0.0300  0.05
# 20201204  0.015  0.0050 -0.05
# 20201203 -0.025  0.0015 -0.20
# 20201202 -0.030  0.0150  0.03

# %%
df.sort_index()
# Out:
#            AAPL    MSFT  TSLA
# 20201201 -0.010  0.0300  0.05
# 20201202 -0.030  0.0150  0.03
# 20201203 -0.025  0.0015 -0.20
# 20201204  0.015  0.0050 -0.05

# %%
df=df.sort_index(axis=1,ascending=False)
df.sort_index(axis=1)
# Out:
#            AAPL    MSFT  TSLA
# 20201201 -0.010  0.0300  0.05
# 20201204  0.015  0.0050 -0.05
# 20201203 -0.025  0.0015 -0.20
# 20201202 -0.030  0.0150  0.03

# %%
df.sort_values(['AAPL', 'MSFT'])
# Out:
#           TSLA    MSFT   AAPL
# 20201202  0.03  0.0150 -0.030
# 20201203 -0.20  0.0015 -0.025
# 20201201  0.05  0.0300 -0.010
# 20201204 -0.05  0.0050  0.015

# %%
df.sort_values(['AAPL'])
# Out:
#           TSLA    MSFT   AAPL
# 20201202  0.03  0.0150 -0.030
# 20201203 -0.20  0.0015 -0.025
# 20201201  0.05  0.0300 -0.010
# 20201204 -0.05  0.0050  0.015
