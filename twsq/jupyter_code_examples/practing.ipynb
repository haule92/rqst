# %%
import pandas as pd
import numpy as np

from twsq.jupyter_code_examples.pandas_series_practice.RetrieveAndModify import index

data = {'A': [100, 101, 105, 103], 'B': [100, 101, 105, 103]}
dates = pd.date_range('2021-01-01', periods=4)
df = pd.DataFrame(data, index=dates)
df.head()
# Out:
#               A    B
# 2021-01-01  100  100
# 2021-01-02  101  101
# 2021-01-03  105  105
# 2021-01-04  103  103

# %%
df / df.shift() -1
# Out:
#                    A         B
# 2021-01-01       NaN       NaN
# 2021-01-02  0.010000  0.010000
# 2021-01-03  0.039604  0.039604
# 2021-01-04 -0.019048 -0.019048

# %%
import yfinance as yf

# %%
univ = ['SPY', 'TSLA']
prices = yf.download(univ, start='2021-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
prices.index
# Out:
# DatetimeIndex(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15',
#                ...
#                '2026-01-26', '2026-01-27', '2026-01-28', '2026-01-29',
#                '2026-01-30', '2026-02-02', '2026-02-03', '2026-02-04',
#                '2026-02-05', '2026-02-06'],
#               dtype='datetime64[s]', name='Date', length=1280, freq=None)

# %%
spy['return_on_close'] = spy['Close'] / spy['Close'].shift() - 1

# %%
returns_spy = prices / prices.shift() - 1

# %%
prices.columns
# Out:
# MultiIndex([( 'Close',  'SPY'),
#             ( 'Close', 'TSLA'),
#             (  'High',  'SPY'),
#             (  'High', 'TSLA'),
#             (   'Low',  'SPY'),
#             (   'Low', 'TSLA'),
#             (  'Open',  'SPY'),
#             (  'Open', 'TSLA'),
#             ('Volume',  'SPY'),
#             ('Volume', 'TSLA')],
#            names=['Price', 'Ticker'])

# %%
prices['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# (spy['Close', 'SPY'] - spy['Close', 'TSLA']).plot()
prices.plot(y=['Close', (spy['Close', 'SPY'] - spy['Close', 'TSLA'])])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # (spy['Close', 'SPY'] - spy['Close', 'TSLA']).plot()
# ----> 2 prices.plot(y=['Close', (spy['Close', 'SPY'] - spy['Close', 'TSLA'])])
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/plotting/_core.py:1169, in PlotAccessor.__call__(self, *args, **kwargs)
#    1166         except (IndexError, KeyError, TypeError):
#    1167             pass
# -> 1169 data = data[y]
#    1171 if isinstance(data, ABCSeries):
#    1172     label_name = label_kw or y
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
# ...
