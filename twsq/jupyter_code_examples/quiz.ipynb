# %%
def get_excess_ret(ret, bmark, beta=1.0):
    return ret - beta * bmark

# %%
get_excess_ret(0.03)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_excess_ret(0.03)
#
# TypeError: get_excess_ret() missing 1 required positional argument: 'bmark'

# %%
ticker = 'XOM'

# %%
if ticker == 'AAPL':
    sector = 'Tech'
elif ticker == 'XOM':
    sector = 'Energy'
elif ticker == 'GS':
    sector = 'Financials'
else:
    sector = 'missing'

# %%
sector
# Out:
# 'Energy'

# %%
signal = [-2, 0, -3 , 5, 6, 7]

# %%
is_big = []

# %%
for x in signal:
    is_big.append(x>2)

# %%
is_big
# Out:
# [False, False, False, True, True, True]
