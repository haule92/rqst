# %% [markdown]
# # Yahoo Finance: Daily Price Bars
# 1. Install yfinance: pip install yfinance
# 2. Documentation: https://pypi.org/project/yfinance/
# 3. GitHub: https://github.com/ranaroussi/yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
univ = ['AAPL','MSFT','GOOG','AMZN','FB','TSLA','BRK-A','NVDA','V']
stock_px = yf.download(univ, start="2019-01-01", auto_adjust=False)
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
stock_px
# Out:
# Price        Adj Close                                               \
# Ticker            AAPL        AMZN     BRK-A         FB        GOOG
# Date
# 2019-01-02   37.538822   76.956497  304057.0        NaN   51.903214
# 2019-01-03   33.799679   75.014000  287000.0        NaN   50.424809
# 2019-01-04   35.242554   78.769501  292500.0        NaN   53.136963
# 2019-01-07   35.164120   81.475502  295400.0        NaN   53.021828
# 2019-01-08   35.834454   82.829002  294300.0        NaN   53.413391
# ...                ...         ...       ...        ...         ...
# 2026-02-02  270.010010  242.960007  729425.0  42.262001  344.899994
# 2026-02-03  269.480011  238.619995  740150.0  42.258999  340.700012
# 2026-02-04  276.489990  232.990005  757890.0  42.153999  333.339996
# 2026-02-05  275.910004  222.690002  756943.0  42.068001  331.329987
# 2026-02-06  278.119995  210.320007  762570.0  42.419998  323.100006
#
# Price                                                            Close  ...  \
# Ticker            MSFT        NVDA        TSLA           V        AAPL  ...
# Date                                                                    ...
# 2019-01-02   94.612610    3.377166   20.674667  126.589928   39.480000  ...
# 2019-01-03   91.132011    3.173128   20.024000  122.028061   35.547501  ...
# 2019-01-04   95.370468    3.376423   21.179333  127.285156   37.064999  ...
# 2019-01-07   95.492096    3.555173   22.330667  129.580460   36.982498  ...
# 2019-01-08   96.184502    3.466666   22.356667  130.285156   37.687500  ...
# ...                ...         ...         ...         ...         ...  ...
# 2026-02-02  423.369995  185.610001  421.809998  333.839996  270.010010  ...
# 2026-02-03  411.209991  180.339996  421.959991  328.929993  269.480011  ...
# 2026-02-04  414.190002  174.190002  406.010010  329.950012  276.489990  ...
# 2026-02-05  393.670013  171.880005  397.209991  329.130005  275.910004  ...
# 2026-02-06  401.140015  185.410004  411.109985  331.579987  278.119995  ...
#
# Price             Open     Volume                                      \
# Ticker               V       AAPL       AMZN  BRK-A      FB      GOOG
# Date
# 2019-01-02  130.000000  148158800  159662000    400     NaN  30652000
# 2019-01-03  131.210007  365248800  139512000    700     NaN  36822000
# 2019-01-04  130.440002  234428400  183652000    800     NaN  41878000
# 2019-01-07  134.449997  219111200  159864000    600     NaN  39638000
# 2019-01-08  137.970001  164101200  177628000    300     NaN  35298000
# ...                ...        ...        ...    ...     ...       ...
# 2026-02-02  324.829987   73913400   37546100  19900   100.0  22775200
# 2026-02-03  331.649994   64394700   53831300    300  2600.0  25786500
# 2026-02-04  327.109985   90545700   51299900    700  2700.0  36991100
# 2026-02-05  333.000000   52977400  103509200    300   100.0  51842000
# 2026-02-06  331.779999   50420700  179021600    300   200.0  33815900
#
# Price
# Ticker          MSFT       NVDA       TSLA         V
# Date
# 2019-01-02  35329300  508752000  174879000   8788000
# 2019-01-03  42579100  705552000  104478000   9428300
# 2019-01-04  44060600  585620000  110911500  11065800
# 2019-01-07  35656100  709160000  113268000  12928000
# 2019-01-08  31514400  786016000  105127500   9243000
# ...              ...        ...        ...       ...
# 2026-02-02  42219900  165794100   58739500   8502400
# 2026-02-03  61424100  204019600   56886500   9081200
# 2026-02-04  45012400  207014100   74606900   8472300
# 2026-02-05  66289200  206312900   72819800   8339000
# 2026-02-06  53403600  230887800   62559600   7771400
#
# [1785 rows x 54 columns]

# %%
stock_px['Adj Close']['AAPL'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
min_data = yf.download(tickers="AAPL", interval="1m", start='2019-01-01')
min_data
# Out:
# $AAPL: possibly delisted; no price data found  (1m 2019-01-01 -> 2026-02-08 14:16:33-05:00) (Yahoo error = "1m data not available for startTime=1546318800 and endTime=1770578193. Only 8 days worth of 1m granularity data are allowed to be fetched per request.")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: possibly delisted; no price data found  (1m 2019-01-01 -> 2026-02-08 14:16:33-05:00) (Yahoo error = "1m data not available for startTime=1546318800 and endTime=1770578193. Only 8 days worth of 1m granularity data are allowed to be fetched per request.")
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []

# %%
min_data = yf.download(tickers="AAPL", interval="1m", period='5d')
min_data

# %%
# crypto daily bars
univ = ['BTC-USD','ETH-USD','BNB-USD','ADA-USD','LINK-USD','XRP-USD','XLM-USD','DOGE-USD','AVAX-USD']
crypto_px = yf.download(univ, start="2019-01-01")

# %%
crypto_px['Close']['BTC-USD'].plot()

# %%
crypto_px.to_pickle('crypto_px.pk')

# %%
pd.read_pickle('crypto_px.pk')

# %% [markdown]
# # Kraken Downloadable CSV
# https://support.kraken.com/hc/en-us/articles/360047124832-Downloadable-historical-OHLCVT-Open-High-Low-Close-Volume-Trades-data

# %% [markdown]
# # Binance API for more crypto coins and minute bar data
# 1. Install python-binance: pip install python-binance
# 2. Documentation: https://python-binance.readthedocs.io/en/latest/
# 3. GitHub: https://github.com/sammchardy/python-binance

# %%
from binance.client import Client as bnb_client
from datetime import datetime
import pandas as pd 

client = bnb_client() # if you're in the US, please use: client=bnb_client(tld='US')'
px = client.get_historical_klines('BTCUSDT','1d','2018-12-15')

# %%
px

# %%
def format_binance(data):
    columns = ['open_time','open','high','low','close','volume','close_time','quote_volume',
    'num_trades','taker_base_volume','taker_quote_volume','ignore']

    data = pd.DataFrame(data,columns = columns)
    
    # Convert from POSIX timestamp (number of millisecond since jan 1, 1970)
    data['open_time'] = data['open_time'].map(lambda x: datetime.fromtimestamp(x/1000))
    data['close_time'] = data['close_time'].map(lambda x: datetime.fromtimestamp(x/1000))
    return data

# %%
format_binance(px)

# %%
# get all the historical data
px = format_binance(client.get_historical_klines('BTCUSDT','1d',0))

# %%
px

# %%
# interval strings
client.KLINE_INTERVAL_1MINUTE

# %%
# Get minute bar data
px = client.get_historical_klines('BTCUSDT','1m','2021-10-20 23:00:00')

# %%
px = format_binance(px)
px

# %%
px.to_pickle('BINANCE_BTCUSDT_1M.pk')

# %%
pd.read_pickle('BINANCE_BTCUSDT_1M.pk')

# %% [markdown]
# # Other
# - We will add to this as class goes on (pandas datareader, ccxt, quandl, simfin)
