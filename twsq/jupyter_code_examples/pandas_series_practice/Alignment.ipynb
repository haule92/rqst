# %% [markdown]
# # Series Data Alignment
# 1. Arithmetic alignment
# 2. Boolean alignment

# %% [markdown]
# #### Arithmetic Alignment

# %%
import pandas as pd
ret1=pd.Series({'VXX':0.01,'AAPL':0.01,'LULU':-0.01,'TSLA':-0.03,'MSFT':-0.01})
ret1
# Out:
# VXX     0.01
# AAPL    0.01
# LULU   -0.01
# TSLA   -0.03
# MSFT   -0.01
# dtype: float64

# %%
ret2=pd.Series({'VXX':0.02,'AAPL':-0.01,'LULU':0.02,'TSLA':-0.04,'MSFT':-0.02})
ret2
# Out:
# VXX     0.02
# AAPL   -0.01
# LULU    0.02
# TSLA   -0.04
# MSFT   -0.02
# dtype: float64

# %%
ret2+ret1
# Out:
# VXX     0.03
# AAPL    0.00
# LULU    0.01
# TSLA   -0.07
# MSFT   -0.03
# dtype: float64

# %%
ret3=pd.Series({'TSLA':-0.01,'AAPL':0.02})
ret3
# Out:
# TSLA   -0.01
# AAPL    0.02
# dtype: float64

# %%
ret1+ret3
# Out:
# AAPL    0.03
# LULU     NaN
# MSFT     NaN
# TSLA   -0.04
# VXX      NaN
# dtype: float64

# %%
ret1.add(ret3,fill_value=0)
# see also "sub","div","mul"
# Out:
# AAPL    0.03
# LULU   -0.01
# MSFT   -0.01
# TSLA   -0.04
# VXX     0.01
# dtype: float64

# %% [markdown]
# #### Boolean Alignment

# %%
ret1 > ret2
# Out:
# VXX     False
# AAPL     True
# LULU    False
# TSLA     True
# MSFT     True
# dtype: bool

# %%
ret1 > ret3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ret1 > ret3
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~/rqst/.venv/lib/python3.12/site-packages/pandas/core/series.py:6730, in Series._cmp_method(self, other, op)
#    6727 res_name = ops.get_op_result_name(self, other)
#    6729 if isinstance(other, Series) and not self._indexed_same(other):
# -> 6730     raise ValueError("Can only compare identically-labeled Series objects")
#    6732 lvalues = self._values
#    6733 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
bool1 = (ret1 > 0)
bool1
# Out:
# VXX      True
# AAPL     True
# LULU    False
# TSLA    False
# MSFT    False
# dtype: bool

# %%
bool2 = (ret2 > 0)
bool2
# Out:
# VXX      True
# AAPL    False
# LULU     True
# TSLA    False
# MSFT    False
# dtype: bool

# %%
bool1 & bool2
# Out:
# VXX      True
# AAPL    False
# LULU    False
# TSLA    False
# MSFT    False
# dtype: bool

# %%
bool1 | bool2
# Out:
# VXX      True
# AAPL     True
# LULU     True
# TSLA    False
# MSFT    False
# dtype: bool

# %%
bool2 & bool1[['MSFT','TSLA','LULU','AAPL','VXX']]
# Out:
# AAPL    False
# LULU    False
# MSFT    False
# TSLA    False
# VXX      True
# dtype: bool

# %%
bool2 & bool1[['VXX']]
# Out:
# AAPL    False
# LULU    False
# MSFT    False
# TSLA    False
# VXX      True
# dtype: bool
